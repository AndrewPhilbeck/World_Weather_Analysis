# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2ce02ec5486fcfb30430ac99466f01ab

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Current Description": city_weather_description,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | ilo
# Processing Record 4 of Set 1 | cam ranh
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | whitehorse
# Processing Record 7 of Set 1 | pyaozerskiy
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | atuona
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | cidreira
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | payson
# Processing Record 16 of Set 1 | tasiilaq
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | tura
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | pangnirtung
# Processing Record 22 of Set 1 | ampanihy
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | grindavik
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | murgab
# Processing Record 28 of Set 1 | bac lieu
# Processing Record 29 of Set 1 | san quintin
# Processing Record 30 of Set 1 | yulara
# Processing Record 31 of Set 1 | puerto escondido
# Processing Record 32 of Set 1 | asau
# Processing Record 33 of Set 1 | mamakan
# Processing Record 34 of Set 1 | bunde
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | micheweni
# Processing Record 37 of Set 1 | general roca
# Processing Record 38 of Set 1 | changji
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | suez
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | la baule-escoublac
# Processing Record 45 of Set 1 | oxelosund
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | cayenne
# Processing Record 49 of Set 1 | grenada
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | sao filipe
# Processing Record 2 of Set 2 | lagoa
# Processing Record 3 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 2 | klaksvik
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | cabo san lucas
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | palana
# Processing Record 9 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 2 | rio tercero
# Processing Record 11 of Set 2 | honiara
# Processing Record 12 of Set 2 | krikellos
# Processing Record 13 of Set 2 | kalmar
# Processing Record 14 of Set 2 | tiarei
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | aklavik
# Processing Record 17 of Set 2 | ternate
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | clyde river
# Processing Record 20 of Set 2 | hambantota
# Processing Record 21 of Set 2 | vila praia de ancora
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | stornoway
# Processing Record 24 of Set 2 | porto santo
# Processing Record 25 of Set 2 | hailar
# Processing Record 26 of Set 2 | margate
# Processing Record 27 of Set 2 | isangel
# Processing Record 28 of Set 2 | totness
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | plettenberg bay
# Processing Record 33 of Set 2 | katsuura
# Processing Record 34 of Set 2 | bredasdorp
# Processing Record 35 of Set 2 | kirakira
# Processing Record 36 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 2 | antalya
# Processing Record 38 of Set 2 | beitbridge
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | nikolskoye
# Processing Record 42 of Set 2 | bethel
# Processing Record 43 of Set 2 | minudasht
# Processing Record 44 of Set 2 | redding
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | kysyl-syr
# Processing Record 47 of Set 2 | dudinka
# Processing Record 48 of Set 2 | pisco
# Processing Record 49 of Set 2 | lulea
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | nata
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | pulaski
# Processing Record 6 of Set 3 | srivardhan
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | muisne
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | cozumel
# Processing Record 12 of Set 3 | kununurra
# Processing Record 13 of Set 3 | fare
# Processing Record 14 of Set 3 | hamilton
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | boulder city
# Processing Record 17 of Set 3 | iquique
# Processing Record 18 of Set 3 | balkhash
# Processing Record 19 of Set 3 | luderitz
# Processing Record 20 of Set 3 | rantoul
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | aksarka
# Processing Record 23 of Set 3 | ouallam
# Processing Record 24 of Set 3 | kobojango
# City not found. Skipping...
# Processing Record 25 of Set 3 | avera
# Processing Record 26 of Set 3 | erenhot
# Processing Record 27 of Set 3 | llangefni
# Processing Record 28 of Set 3 | caravelas
# Processing Record 29 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 3 | vaini
# Processing Record 31 of Set 3 | ayorou
# Processing Record 32 of Set 3 | kaberamaido
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | kohlu
# Processing Record 35 of Set 3 | porto velho
# Processing Record 36 of Set 3 | flinders
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | wabana
# Processing Record 39 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 3 | sovetskiy
# Processing Record 41 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 3 | san patricio
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | mayo
# Processing Record 45 of Set 3 | torbay
# Processing Record 46 of Set 3 | port elizabeth
# Processing Record 47 of Set 3 | salalah
# Processing Record 48 of Set 3 | kalmunai
# Processing Record 49 of Set 3 | saulkrasti
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 4 | urkut
# Processing Record 3 of Set 4 | redlands
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | castro
# Processing Record 7 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 4 | upata
# Processing Record 9 of Set 4 | gondanglegi
# Processing Record 10 of Set 4 | saint-denis
# Processing Record 11 of Set 4 | okato
# Processing Record 12 of Set 4 | bluff
# Processing Record 13 of Set 4 | roald
# Processing Record 14 of Set 4 | clive
# Processing Record 15 of Set 4 | corinto
# Processing Record 16 of Set 4 | safaqis
# City not found. Skipping...
# Processing Record 17 of Set 4 | moskovskoye
# Processing Record 18 of Set 4 | sambava
# Processing Record 19 of Set 4 | naze
# Processing Record 20 of Set 4 | cherskiy
# Processing Record 21 of Set 4 | saskylakh
# Processing Record 22 of Set 4 | saldanha
# Processing Record 23 of Set 4 | nanortalik
# Processing Record 24 of Set 4 | tuktoyaktuk
# Processing Record 25 of Set 4 | ferrol
# Processing Record 26 of Set 4 | whyalla
# Processing Record 27 of Set 4 | alofi
# Processing Record 28 of Set 4 | karratha
# Processing Record 29 of Set 4 | macia
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | katangli
# Processing Record 32 of Set 4 | te anau
# Processing Record 33 of Set 4 | ketchikan
# Processing Record 34 of Set 4 | sisimiut
# Processing Record 35 of Set 4 | lakshmeshwar
# Processing Record 36 of Set 4 | antsohihy
# Processing Record 37 of Set 4 | geraldton
# Processing Record 38 of Set 4 | bambous virieux
# Processing Record 39 of Set 4 | waipawa
# Processing Record 40 of Set 4 | borogontsy
# Processing Record 41 of Set 4 | uinskoye
# Processing Record 42 of Set 4 | katubao
# Processing Record 43 of Set 4 | aripuana
# Processing Record 44 of Set 4 | hasaki
# Processing Record 45 of Set 4 | imeni poliny osipenko
# Processing Record 46 of Set 4 | oktyabrskoye
# Processing Record 47 of Set 4 | harper
# Processing Record 48 of Set 4 | praia
# Processing Record 49 of Set 4 | neepawa
# Processing Record 50 of Set 4 | pavlodar
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | waingapu
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 5 | zhuji
# Processing Record 5 of Set 5 | makokou
# Processing Record 6 of Set 5 | oropesa
# Processing Record 7 of Set 5 | okhotsk
# Processing Record 8 of Set 5 | necochea
# Processing Record 9 of Set 5 | kupang
# Processing Record 10 of Set 5 | homa bay
# Processing Record 11 of Set 5 | ozernovskiy
# Processing Record 12 of Set 5 | djang
# City not found. Skipping...
# Processing Record 13 of Set 5 | sibu
# Processing Record 14 of Set 5 | vila velha
# Processing Record 15 of Set 5 | nantucket
# Processing Record 16 of Set 5 | moree
# Processing Record 17 of Set 5 | wattegama
# Processing Record 18 of Set 5 | comodoro rivadavia
# Processing Record 19 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 5 | tubmanburg
# Processing Record 21 of Set 5 | riyadh
# Processing Record 22 of Set 5 | yar-sale
# Processing Record 23 of Set 5 | luwuk
# Processing Record 24 of Set 5 | lodja
# Processing Record 25 of Set 5 | abha
# Processing Record 26 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 5 | barcelos
# Processing Record 28 of Set 5 | trnava
# Processing Record 29 of Set 5 | petushki
# Processing Record 30 of Set 5 | taraz
# Processing Record 31 of Set 5 | tumba
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | ponnani
# Processing Record 34 of Set 5 | burnie
# Processing Record 35 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 5 | luau
# Processing Record 37 of Set 5 | voroshnevo
# Processing Record 38 of Set 5 | mabaruma
# Processing Record 39 of Set 5 | miraflores
# Processing Record 40 of Set 5 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 5 | lazaro cardenas
# Processing Record 42 of Set 5 | roma
# Processing Record 43 of Set 5 | elblag
# Processing Record 44 of Set 5 | chimoio
# Processing Record 45 of Set 5 | biak
# Processing Record 46 of Set 5 | puerto del rosario
# Processing Record 47 of Set 5 | ola
# Processing Record 48 of Set 5 | ranong
# Processing Record 49 of Set 5 | grand gaube
# Processing Record 50 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 6 | fayaoue
# Processing Record 3 of Set 6 | longyearbyen
# Processing Record 4 of Set 6 | harlingen
# Processing Record 5 of Set 6 | college
# Processing Record 6 of Set 6 | zhovtneve
# Processing Record 7 of Set 6 | mount gambier
# Processing Record 8 of Set 6 | bagdarin
# Processing Record 9 of Set 6 | port hardy
# Processing Record 10 of Set 6 | broken hill
# Processing Record 11 of Set 6 | enshi
# Processing Record 12 of Set 6 | mahebourg
# Processing Record 13 of Set 6 | brae
# Processing Record 14 of Set 6 | avarua
# Processing Record 15 of Set 6 | baruun-urt
# Processing Record 16 of Set 6 | codrington
# Processing Record 17 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 6 | saint-augustin
# Processing Record 19 of Set 6 | taoudenni
# Processing Record 20 of Set 6 | wanaka
# Processing Record 21 of Set 6 | lorengau
# Processing Record 22 of Set 6 | takoradi
# Processing Record 23 of Set 6 | yei
# Processing Record 24 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 6 | rognan
# Processing Record 26 of Set 6 | nosy varika
# Processing Record 27 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 6 | villa rica
# Processing Record 29 of Set 6 | hong gai
# Processing Record 30 of Set 6 | huarmey
# Processing Record 31 of Set 6 | celestun
# Processing Record 32 of Set 6 | adrar
# Processing Record 33 of Set 6 | faanui
# Processing Record 34 of Set 6 | natal
# Processing Record 35 of Set 6 | rafaela
# Processing Record 36 of Set 6 | ilulissat
# Processing Record 37 of Set 6 | atambua
# Processing Record 38 of Set 6 | domoni
# Processing Record 39 of Set 6 | husavik
# Processing Record 40 of Set 6 | rocha
# Processing Record 41 of Set 6 | champerico
# Processing Record 42 of Set 6 | nizhneangarsk
# Processing Record 43 of Set 6 | burica
# City not found. Skipping...
# Processing Record 44 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 6 | erzincan
# Processing Record 46 of Set 6 | angoche
# Processing Record 47 of Set 6 | sobolevo
# Processing Record 48 of Set 6 | suao
# City not found. Skipping...
# Processing Record 49 of Set 6 | weihai
# Processing Record 50 of Set 6 | sioux lookout
# Processing Record 1 of Set 7 | narsaq
# Processing Record 2 of Set 7 | jalcocotan
# Processing Record 3 of Set 7 | urfa
# City not found. Skipping...
# Processing Record 4 of Set 7 | port hawkesbury
# Processing Record 5 of Set 7 | hualmay
# Processing Record 6 of Set 7 | krizevci
# Processing Record 7 of Set 7 | dingle
# Processing Record 8 of Set 7 | lake city
# Processing Record 9 of Set 7 | edd
# Processing Record 10 of Set 7 | tabas
# Processing Record 11 of Set 7 | mantua
# Processing Record 12 of Set 7 | veselynove
# Processing Record 13 of Set 7 | thompson
# Processing Record 14 of Set 7 | cangzhou
# Processing Record 15 of Set 7 | flagstaff
# Processing Record 16 of Set 7 | lewiston
# Processing Record 17 of Set 7 | skaerbaek
# Processing Record 18 of Set 7 | kruisfontein
# Processing Record 19 of Set 7 | beterou
# Processing Record 20 of Set 7 | port blair
# Processing Record 21 of Set 7 | pilot butte
# Processing Record 22 of Set 7 | laguna
# Processing Record 23 of Set 7 | ambilobe
# Processing Record 24 of Set 7 | kelo
# Processing Record 25 of Set 7 | marsh harbour
# Processing Record 26 of Set 7 | korla
# Processing Record 27 of Set 7 | ndele
# Processing Record 28 of Set 7 | jaguaruana
# Processing Record 29 of Set 7 | ahuimanu
# Processing Record 30 of Set 7 | svetlaya
# Processing Record 31 of Set 7 | brazzaville
# Processing Record 32 of Set 7 | amapa
# Processing Record 33 of Set 7 | los llanos de aridane
# Processing Record 34 of Set 7 | balaghat
# Processing Record 35 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 7 | provideniya
# Processing Record 37 of Set 7 | baykit
# Processing Record 38 of Set 7 | kalaleh
# Processing Record 39 of Set 7 | souillac
# Processing Record 40 of Set 7 | kodiak
# Processing Record 41 of Set 7 | ulaanbaatar
# Processing Record 42 of Set 7 | saint anthony
# Processing Record 43 of Set 7 | umba
# Processing Record 44 of Set 7 | izhma
# Processing Record 45 of Set 7 | hami
# Processing Record 46 of Set 7 | tigil
# Processing Record 47 of Set 7 | bilibino
# Processing Record 48 of Set 7 | samarai
# Processing Record 49 of Set 7 | mikhaylovka
# Processing Record 50 of Set 7 | kieta
# Processing Record 1 of Set 8 | wuchi
# Processing Record 2 of Set 8 | nanzhang
# Processing Record 3 of Set 8 | mwembe
# Processing Record 4 of Set 8 | valera
# Processing Record 5 of Set 8 | edgewater
# Processing Record 6 of Set 8 | warmbad
# Processing Record 7 of Set 8 | sokoto
# Processing Record 8 of Set 8 | irbil
# Processing Record 9 of Set 8 | victoria
# Processing Record 10 of Set 8 | gamba
# Processing Record 11 of Set 8 | iqaluit
# Processing Record 12 of Set 8 | omboue
# Processing Record 13 of Set 8 | asilah
# Processing Record 14 of Set 8 | zilair
# Processing Record 15 of Set 8 | cedar city
# Processing Record 16 of Set 8 | huaicheng
# Processing Record 17 of Set 8 | isla vista
# Processing Record 18 of Set 8 | egvekinot
# Processing Record 19 of Set 8 | gobabis
# Processing Record 20 of Set 8 | fuyang
# Processing Record 21 of Set 8 | sokoni
# Processing Record 22 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 8 | vertientes
# Processing Record 24 of Set 8 | tiznit
# Processing Record 25 of Set 8 | faya
# Processing Record 26 of Set 8 | dauriya
# Processing Record 27 of Set 8 | muros
# Processing Record 28 of Set 8 | romitan
# Processing Record 29 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 8 | saleilua
# City not found. Skipping...
# Processing Record 31 of Set 8 | rock sound
# Processing Record 32 of Set 8 | strizhi
# Processing Record 33 of Set 8 | jalpan
# Processing Record 34 of Set 8 | pucallpa
# Processing Record 35 of Set 8 | qaqortoq
# Processing Record 36 of Set 8 | tiksi
# Processing Record 37 of Set 8 | wajir
# Processing Record 38 of Set 8 | dunedin
# Processing Record 39 of Set 8 | tabuk
# Processing Record 40 of Set 8 | fairbanks
# Processing Record 41 of Set 8 | cambridge
# Processing Record 42 of Set 8 | rovaniemi
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 8 | bideford
# Processing Record 46 of Set 8 | sohag
# Processing Record 47 of Set 8 | constitucion
# Processing Record 48 of Set 8 | mount isa
# Processing Record 49 of Set 8 | port maria
# Processing Record 50 of Set 8 | jamame
# Processing Record 1 of Set 9 | boffa
# Processing Record 2 of Set 9 | jalandhar
# Processing Record 3 of Set 9 | mancio lima
# Processing Record 4 of Set 9 | tongsa
# City not found. Skipping...
# Processing Record 5 of Set 9 | muravlenko
# Processing Record 6 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | madhipura
# Processing Record 8 of Set 9 | sal rei
# Processing Record 9 of Set 9 | kholodnyy
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | sao francisco do sul
# Processing Record 12 of Set 9 | moramanga
# Processing Record 13 of Set 9 | barentu
# Processing Record 14 of Set 9 | starobaltachevo
# Processing Record 15 of Set 9 | mattru
# Processing Record 16 of Set 9 | swan hill
# Processing Record 17 of Set 9 | bay roberts
# Processing Record 18 of Set 9 | altay
# Processing Record 19 of Set 9 | troyes
# Processing Record 20 of Set 9 | yarmouth
# Processing Record 21 of Set 9 | vardo
# Processing Record 22 of Set 9 | amalapuram
# Processing Record 23 of Set 9 | linxia
# Processing Record 24 of Set 9 | turinsk
# Processing Record 25 of Set 9 | hit
# Processing Record 26 of Set 9 | ust-maya
# Processing Record 27 of Set 9 | gravdal
# Processing Record 28 of Set 9 | west bay
# Processing Record 29 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 30 of Set 9 | tilichiki
# Processing Record 31 of Set 9 | ponot
# Processing Record 32 of Set 9 | poopo
# Processing Record 33 of Set 9 | vesyegonsk
# Processing Record 34 of Set 9 | kahului
# Processing Record 35 of Set 9 | awjilah
# Processing Record 36 of Set 9 | matagami
# Processing Record 37 of Set 9 | kabo
# Processing Record 38 of Set 9 | shubarshi
# Processing Record 39 of Set 9 | batemans bay
# Processing Record 40 of Set 9 | adamas
# Processing Record 41 of Set 9 | oeiras do para
# Processing Record 42 of Set 9 | lima
# Processing Record 43 of Set 9 | nalut
# Processing Record 44 of Set 9 | coihaique
# Processing Record 45 of Set 9 | sechura
# Processing Record 46 of Set 9 | mashivka
# Processing Record 47 of Set 9 | panalingaan
# Processing Record 48 of Set 9 | beloha
# Processing Record 49 of Set 9 | ranot
# Processing Record 50 of Set 9 | manzhouli
# Processing Record 1 of Set 10 | granja
# Processing Record 2 of Set 10 | batagay
# Processing Record 3 of Set 10 | abonnema
# Processing Record 4 of Set 10 | kingswood
# Processing Record 5 of Set 10 | talnakh
# Processing Record 6 of Set 10 | qandala
# Processing Record 7 of Set 10 | ostrovnoy
# Processing Record 8 of Set 10 | meadow lake
# Processing Record 9 of Set 10 | barguzin
# Processing Record 10 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 11 of Set 10 | santomera
# Processing Record 12 of Set 10 | abu samrah
# Processing Record 13 of Set 10 | ferme-neuve
# Processing Record 14 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 10 | sola
# Processing Record 16 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 17 of Set 10 | bell ville
# Processing Record 18 of Set 10 | abalak
# Processing Record 19 of Set 10 | kendal
# Processing Record 20 of Set 10 | villa maria
# Processing Record 21 of Set 10 | port macquarie
# Processing Record 22 of Set 10 | semnan
# Processing Record 23 of Set 10 | mahaicony
# City not found. Skipping...
# Processing Record 24 of Set 10 | rosetta
# Processing Record 25 of Set 10 | chara
# Processing Record 26 of Set 10 | takaungu
# Processing Record 27 of Set 10 | ponta delgada
# Processing Record 28 of Set 10 | noumea
# Processing Record 29 of Set 10 | palasa
# Processing Record 30 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 10 | berlevag
# Processing Record 32 of Set 10 | kozhevnikovo
# Processing Record 33 of Set 10 | san carlos de bariloche
# Processing Record 34 of Set 10 | obo
# Processing Record 35 of Set 10 | tala
# Processing Record 36 of Set 10 | chichibu
# Processing Record 37 of Set 10 | kloulklubed
# Processing Record 38 of Set 10 | northam
# Processing Record 39 of Set 10 | santa maria
# Processing Record 40 of Set 10 | pevek
# Processing Record 41 of Set 10 | itarema
# Processing Record 42 of Set 10 | frogner
# Processing Record 43 of Set 10 | jalu
# Processing Record 44 of Set 10 | pando
# Processing Record 45 of Set 10 | macamic
# Processing Record 46 of Set 10 | tynda
# Processing Record 47 of Set 10 | nagato
# Processing Record 48 of Set 10 | maniitsoq
# Processing Record 49 of Set 10 | katobu
# Processing Record 50 of Set 10 | abu kamal
# Processing Record 1 of Set 11 | oum hadjer
# Processing Record 2 of Set 11 | ayutla
# Processing Record 3 of Set 11 | cap malheureux
# Processing Record 4 of Set 11 | taihe
# Processing Record 5 of Set 11 | guerrero negro
# Processing Record 6 of Set 11 | baglan
# Processing Record 7 of Set 11 | chiapilla
# Processing Record 8 of Set 11 | bantry
# Processing Record 9 of Set 11 | satipo
# Processing Record 10 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 11 | richards bay
# Processing Record 12 of Set 11 | rio claro
# Processing Record 13 of Set 11 | conde
# Processing Record 14 of Set 11 | taksimo
# Processing Record 15 of Set 11 | abu dhabi
# Processing Record 16 of Set 11 | bose
# Processing Record 17 of Set 11 | imphal
# Processing Record 18 of Set 11 | san cristobal
# Processing Record 19 of Set 11 | zhanaozen
# Processing Record 20 of Set 11 | buraydah
# Processing Record 21 of Set 11 | ustye
# Processing Record 22 of Set 11 | namibe
# Processing Record 23 of Set 11 | montlucon
# Processing Record 24 of Set 11 | kokopo
# Processing Record 25 of Set 11 | dindori
# Processing Record 26 of Set 11 | esfarayen
# Processing Record 27 of Set 11 | havelock
# Processing Record 28 of Set 11 | road town
# Processing Record 29 of Set 11 | tezu
# Processing Record 30 of Set 11 | saint-leu
# Processing Record 31 of Set 11 | port lincoln
# Processing Record 32 of Set 11 | lasalgaon
# Processing Record 33 of Set 11 | la ronge
# Processing Record 34 of Set 11 | touros
# Processing Record 35 of Set 11 | eureka
# Processing Record 36 of Set 11 | langsa
# Processing Record 37 of Set 11 | coahuayana
# Processing Record 38 of Set 11 | frolishchi
# Processing Record 39 of Set 11 | san juan bautista
# Processing Record 40 of Set 11 | krasnaya gorbatka
# Processing Record 41 of Set 11 | andenes
# Processing Record 42 of Set 11 | praia da vitoria
# Processing Record 43 of Set 11 | ulladulla
# Processing Record 44 of Set 11 | gejiu
# Processing Record 45 of Set 11 | komarikhinskiy
# Processing Record 46 of Set 11 | puqi
# Processing Record 47 of Set 11 | rjukan
# Processing Record 48 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 11 | lloydminster
# Processing Record 50 of Set 11 | albury
# Processing Record 1 of Set 12 | brigantine
# Processing Record 2 of Set 12 | sitka
# Processing Record 3 of Set 12 | gunjur
# Processing Record 4 of Set 12 | peniche
# Processing Record 5 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 6 of Set 12 | vicuna
# Processing Record 7 of Set 12 | manggar
# Processing Record 8 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 12 | voh
# Processing Record 10 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 11 of Set 12 | sinnamary
# Processing Record 12 of Set 12 | shaunavon
# Processing Record 13 of Set 12 | olafsvik
# Processing Record 14 of Set 12 | walvis bay
# Processing Record 15 of Set 12 | port hedland
# Processing Record 16 of Set 12 | nicoya
# Processing Record 17 of Set 12 | thinadhoo
# Processing Record 18 of Set 12 | ulkan
# Processing Record 19 of Set 12 | san carlos
# Processing Record 20 of Set 12 | agirish
# Processing Record 21 of Set 12 | superior
# Processing Record 22 of Set 12 | bitaogan
# Processing Record 23 of Set 12 | westport
# Processing Record 24 of Set 12 | zanesville
# Processing Record 25 of Set 12 | yerbogachen
# Processing Record 26 of Set 12 | glendive
# Processing Record 27 of Set 12 | cheremnoye
# Processing Record 28 of Set 12 | alta floresta
# Processing Record 29 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 12 | camacha
# Processing Record 31 of Set 12 | portland
# Processing Record 32 of Set 12 | santa cecilia
# Processing Record 33 of Set 12 | raybag
# Processing Record 34 of Set 12 | sabang
# Processing Record 35 of Set 12 | sibolga
# Processing Record 36 of Set 12 | sokolo
# Processing Record 37 of Set 12 | kinshasa
# Processing Record 38 of Set 12 | blagoyevo
# Processing Record 39 of Set 12 | roseburg
# Processing Record 40 of Set 12 | hervey bay
# Processing Record 41 of Set 12 | illapel
# Processing Record 42 of Set 12 | kulunda
# Processing Record 43 of Set 12 | moose factory
# Processing Record 44 of Set 12 | manaure
# Processing Record 45 of Set 12 | maragogi
# Processing Record 46 of Set 12 | ilhabela
# Processing Record 47 of Set 12 | homer
# Processing Record 48 of Set 12 | san andres
# Processing Record 49 of Set 12 | zamora
# Processing Record 50 of Set 12 | port arthur
# Processing Record 1 of Set 13 | mahibadhoo
# Processing Record 2 of Set 13 | haines junction
# Processing Record 3 of Set 13 | pitimbu
# Processing Record 4 of Set 13 | gasa
# Processing Record 5 of Set 13 | amahai
# Processing Record 6 of Set 13 | kailua
# Processing Record 7 of Set 13 | dakar
# Processing Record 8 of Set 13 | filingue
# Processing Record 9 of Set 13 | gambela
# Processing Record 10 of Set 13 | da lat
# Processing Record 11 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 13 | matara
# Processing Record 13 of Set 13 | carazinho
# Processing Record 14 of Set 13 | syracuse
# Processing Record 15 of Set 13 | quelimane
# Processing Record 16 of Set 13 | juybar
# Processing Record 17 of Set 13 | kaduna
# Processing Record 18 of Set 13 | salinopolis
# Processing Record 19 of Set 13 | padang
# Processing Record 20 of Set 13 | kez
# Processing Record 21 of Set 13 | nouakchott
# Processing Record 22 of Set 13 | san miguel
# Processing Record 23 of Set 13 | vao
# Processing Record 24 of Set 13 | nikoklia
# Processing Record 25 of Set 13 | kamina
# Processing Record 26 of Set 13 | chiredzi
# Processing Record 27 of Set 13 | chapleau
# Processing Record 28 of Set 13 | oistins
# Processing Record 29 of Set 13 | pochutla
# Processing Record 30 of Set 13 | borba
# Processing Record 31 of Set 13 | acari
# Processing Record 32 of Set 13 | mari-turek
# Processing Record 33 of Set 13 | nome
# Processing Record 34 of Set 13 | anloga
# Processing Record 35 of Set 13 | teya
# Processing Record 36 of Set 13 | beyneu
# Processing Record 37 of Set 13 | north bend
# Processing Record 38 of Set 13 | sao borja
# Processing Record 39 of Set 13 | bismil
# Processing Record 40 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 13 | mokhsogollokh
# Processing Record 42 of Set 13 | cloquet
# Processing Record 43 of Set 13 | lagunas
# Processing Record 44 of Set 13 | bonavista
# Processing Record 45 of Set 13 | neryungri
# Processing Record 46 of Set 13 | raudeberg
# Processing Record 47 of Set 13 | ust-kalmanka
# Processing Record 48 of Set 13 | clearlake
# Processing Record 49 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 13 | verkhnyaya inta
# Processing Record 1 of Set 14 | terney
# Processing Record 2 of Set 14 | sidmouth
# Processing Record 3 of Set 14 | leh
# Processing Record 4 of Set 14 | taltal
# Processing Record 5 of Set 14 | grimari
# City not found. Skipping...
# Processing Record 6 of Set 14 | varberg
# Processing Record 7 of Set 14 | rio grande
# Processing Record 8 of Set 14 | ust-ilimsk
# Processing Record 9 of Set 14 | skjervoy
# Processing Record 10 of Set 14 | dese
# Processing Record 11 of Set 14 | strausberg
# Processing Record 12 of Set 14 | port lavaca
# Processing Record 13 of Set 14 | hovd
# Processing Record 14 of Set 14 | deputatskiy
# Processing Record 15 of Set 14 | penzance
# Processing Record 16 of Set 14 | lavrentiya
# Processing Record 17 of Set 14 | tsuruoka
# Processing Record 18 of Set 14 | cradock
# Processing Record 19 of Set 14 | makakilo city
# Processing Record 20 of Set 14 | rioblanco
# Processing Record 21 of Set 14 | huambo
# Processing Record 22 of Set 14 | oranjestad
# Processing Record 23 of Set 14 | ayan
# Processing Record 24 of Set 14 | pitanga
# Processing Record 25 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 26 of Set 14 | juneau
# Processing Record 27 of Set 14 | ancud
# Processing Record 28 of Set 14 | aiken
# Processing Record 29 of Set 14 | cockburn town
# Processing Record 30 of Set 14 | pemangkat
# Processing Record 31 of Set 14 | atar
# Processing Record 32 of Set 14 | busteni
# Processing Record 33 of Set 14 | port-gentil
# Processing Record 34 of Set 14 | kartuzy
# Processing Record 35 of Set 14 | yaring
# Processing Record 36 of Set 14 | bilma
# Processing Record 37 of Set 14 | maltahohe
# Processing Record 38 of Set 14 | nijar
# Processing Record 39 of Set 14 | nizhniy odes
# Processing Record 40 of Set 14 | nacogdoches
# Processing Record 41 of Set 14 | paamiut
# Processing Record 42 of Set 14 | cervo
# Processing Record 43 of Set 14 | panjakent
# Processing Record 44 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 14 | viesca
# Processing Record 46 of Set 14 | zhigansk
# Processing Record 47 of Set 14 | alakurtti
# Processing Record 48 of Set 14 | birjand
# Processing Record 49 of Set 14 | uni
# Processing Record 50 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 15 | leshukonskoye
# Processing Record 2 of Set 15 | otane
# Processing Record 3 of Set 15 | nemuro
# Processing Record 4 of Set 15 | warwick
# Processing Record 5 of Set 15 | san
# Processing Record 6 of Set 15 | aberdeen
# Processing Record 7 of Set 15 | valparaiso
# Processing Record 8 of Set 15 | moerai
# Processing Record 9 of Set 15 | mehamn
# Processing Record 10 of Set 15 | lasa
# Processing Record 11 of Set 15 | shelabolikha
# Processing Record 12 of Set 15 | wenling
# Processing Record 13 of Set 15 | beausejour
# Processing Record 14 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 15 | ewa beach
# Processing Record 16 of Set 15 | nanakuli
# Processing Record 17 of Set 15 | sijunjung
# Processing Record 18 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 15 | lata
# Processing Record 20 of Set 15 | toba
# Processing Record 21 of Set 15 | kaeo
# Processing Record 22 of Set 15 | kasongo-lunda
# Processing Record 23 of Set 15 | usinsk
# Processing Record 24 of Set 15 | mentok
# City not found. Skipping...
# Processing Record 25 of Set 15 | palmer
# Processing Record 26 of Set 15 | kushmurun
# Processing Record 27 of Set 15 | todos santos
# Processing Record 28 of Set 15 | ikalamavony
# Processing Record 29 of Set 15 | auki
# Processing Record 30 of Set 15 | karera
# Processing Record 31 of Set 15 | martapura
# Processing Record 32 of Set 15 | azimur
# City not found. Skipping...
# Processing Record 33 of Set 15 | havre
# Processing Record 34 of Set 15 | pericos
# Processing Record 35 of Set 15 | searcy
# Processing Record 36 of Set 15 | pavlogradka
# Processing Record 37 of Set 15 | ornskoldsvik
# Processing Record 38 of Set 15 | tonekabon
# Processing Record 39 of Set 15 | pinerovka
# Processing Record 40 of Set 15 | dongsheng
# Processing Record 41 of Set 15 | cairns
# Processing Record 42 of Set 15 | shushenskoye
# Processing Record 43 of Set 15 | the valley
# Processing Record 44 of Set 15 | tanout
# Processing Record 45 of Set 15 | musoma
# Processing Record 46 of Set 15 | buin
# Processing Record 47 of Set 15 | ludvika
# Processing Record 48 of Set 15 | lanzhou
# Processing Record 49 of Set 15 | elban
# Processing Record 50 of Set 15 | grootfontein
# Processing Record 1 of Set 16 | jishou
# Processing Record 2 of Set 16 | olinda
# Processing Record 3 of Set 16 | sirohi
# Processing Record 4 of Set 16 | sembakung
# Processing Record 5 of Set 16 | nushki
# Processing Record 6 of Set 16 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 16 | kandrian
# Processing Record 8 of Set 16 | carauari
# Processing Record 9 of Set 16 | nelson bay
# Processing Record 10 of Set 16 | quincy
# Processing Record 11 of Set 16 | baker city
# Processing Record 12 of Set 16 | lang son
# Processing Record 13 of Set 16 | anadyr
# Processing Record 14 of Set 16 | santa isabel do rio negro
# Processing Record 15 of Set 16 | new amsterdam
# Processing Record 16 of Set 16 | jiroft
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0     New Norfolk -42.7826  147.0587     51.71     overcast clouds        64
# 1     Yellowknife  62.4560 -114.3525    -21.44    scattered clouds        76
# 2             Ilo -17.6394  -71.3375     72.46           clear sky        68
# 3        Cam Ranh  11.9214  109.1591     78.76    scattered clouds        94
# 4       Busselton -33.6500  115.3333     60.57          few clouds        94
# 5      Whitehorse  60.7161 -135.0538    -16.19           clear sky        75
# 6     Pyaozerskiy  65.8333   31.1667     25.27     overcast clouds        98
# 7          Albany  42.6001  -73.9662     46.42     overcast clouds        88
# 8          Atuona  -9.8000 -139.0333     77.56          light rain        76
# 9  Severo-Kurilsk  50.6789  156.1250     32.56          light snow        80
#
#    Cloudiness  Wind Speed Country
# 0          98        1.01      AU
# 1          40        4.61      CA
# 2           0       10.36      PE
# 3          40       13.80      VN
# 4          13        7.76      AU
# 5           0        4.61      CA
# 6         100        3.04      RU
# 7         100       10.00      US
# 8          42       16.53      PF
# 9          85       13.65      RU

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df.loc[:,["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     New Norfolk      AU -42.7826  147.0587     51.71        64          98
# 1     Yellowknife      CA  62.4560 -114.3525    -21.44        76          40
# 2             Ilo      PE -17.6394  -71.3375     72.46        68           0
# 3        Cam Ranh      VN  11.9214  109.1591     78.76        94          40
# 4       Busselton      AU -33.6500  115.3333     60.57        94          13
# 5      Whitehorse      CA  60.7161 -135.0538    -16.19        75           0
# 6     Pyaozerskiy      RU  65.8333   31.1667     25.27        98         100
# 7          Albany      US  42.6001  -73.9662     46.42        88         100
# 8          Atuona      PF  -9.8000 -139.0333     77.56        76          42
# 9  Severo-Kurilsk      RU  50.6789  156.1250     32.56        80          85
#
#    Wind Speed Current Description
# 0        1.01     overcast clouds
# 1        4.61    scattered clouds
# 2       10.36           clear sky
# 3       13.80    scattered clouds
# 4        7.76          few clouds
# 5        4.61           clear sky
# 6        3.04     overcast clouds
# 7       10.00     overcast clouds
# 8       16.53          light rain
# 9       13.65          light snow

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
